# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Admin\Downloads\Downloads Nyts\TraSH\PG Database.xlsx')

# %%
df
# Out:
#       Unnamed: 0 Unnamed: 1    Unnamed: 2      NAME OF THE STUDENT  \
# 0             51        NaN           PUC         SHIVANI R SHETTY
# 1             52        NaN           PUC           MOHAMMED SINAN
# 2             53        NaN           PUC  GOWRISH RAMESH SOMAYAJI
# 3             54        NaN           PUC            AKSHAJ BAKHLE
# 4             55        NaN           PUC              ANUSHA SHET
# ...          ...        ...           ...                      ...
# 59421         46      AMCAT  College demo                DEEPTHI N
# 59422         47      AMCAT  College demo             ANUKIRANA AV
# 59423         48      AMCAT  College demo                NIHA BANU
# 59424         49      AMCAT  College demo                  ROJA HG
# 59425         50      AMCAT  College demo            PRINYANKA M,S
#
#       CONTACT NUMBER  Unnamed: 5 Unnamed: 6  PLACE   Assigned To  \
# 0         8453850949       SU021        NaN  UDUPI  Telecaller 5
# ...

# %%
print(df.loc[df['Willing to Attend Session? Y/N'] == 'mba'])
# Out:
#       Unnamed: 0 Unnamed: 1         Unnamed: 2    NAME OF THE STUDENT  \
# 385          451        NaN                NaN           PRIYANKA B S
# 448          183        NaN                NaN              SHRIRAKSH
# 1032        1806        NaN                NaN          H S DEEKSHITH
# 1235        2614        NaN                NaN              M MAHESHA
# 2026        5611        NaN             Degree             SHASHANK Y
# 2100        6406        NaN             Degree       SUMANTH S SHETTY
# 2191        7215        NaN             Degree  WICKY STEPHEN D SOUZA
# 4146           7        NaN  College Demo Data                 FAUZIN
# 4159          22        NaN  College Demo Data         NITHESH SHETTY
# 4168          32        NaN  College Demo Data        AMRUTHA R ADIGA
# 4181          48        NaN  College Demo Data           PRATHIKSHA K
# 4183          50        NaN  College Demo Data      SUJITH S DEVADIGA
# ...

# %%
print(df.loc[df['Remarks'] == 'mba'])
# Out:
#       Unnamed: 0         Unnamed: 1    Unnamed: 2  NAME OF THE STUDENT  \
# 26173       3262                NaN        Degree      N G DEEPA ACHAR
# 26706       6647                NaN        Degree      SWATHI B SHETTY
# 27887         30                NaN  College Demo           AKSHATHA S
# 28021         72                NaN  College Demo             DIVYA BM
# 31607       1276                NaN        Degree             NAMRATHA
# ...          ...                ...           ...                  ...
# 56361       4064             Degree           NaN       PRAPTHI R AMIN
# 56366       4069             Degree           NaN  PRARTHANA UPADHYAYA
# 56414       4167             Degree           NaN     PRATHIKSHA NAYAK
# 56485       4632             Degree           NaN   RANJITHA R POOJARY
# 57954         39  College Demo Data           NaN             RAKSHITH
#
#       CONTACT NUMBER               Unnamed: 5        Unnamed: 6  PLACE  \
# ...

# %%
print(df.loc[df['Willing to Attend Session? Y/N'] == 'mca'])
# Out:
#       Unnamed: 0 Unnamed: 1         Unnamed: 2 NAME OF THE STUDENT  \
# 6047         720        NaN                 BE  Santhosh Patil M R
# 11548         52        NaN  College Demo Data           NISARGA M
# 12793         52        NaN                 BE           Archana G
# 13246       1246        NaN                 BE      Prajwal Kundap
# 13351       1937        NaN                 BE      Sneha Janawade
#
#       CONTACT NUMBER Unnamed: 5 Unnamed: 6         PLACE Assigned To  \
# 6047      9008400329        NaN        NaN  Mediginakere         NaN
# 11548     9900732317        NaN        NaN           NaN         NaN
# 12793     7406389945        NaN        NaN           NaN         NaN
# 13246     8050803428        NaN        NaN           NaN         NaN
# 13351     9611971797        NaN        NaN           NaN         NaN
#
#            Unnamed: 9  Call Back Date          Unnamed: 11  \
# 6047   Not Interested             NaN  2020-09-29 00:00:00
# ...

# %%
print(df.loc[df['Remarks'] == 'mca'])
# Out:
#       Unnamed: 0    Unnamed: 1         Unnamed: 2       NAME OF THE STUDENT  \
# 26656        138           NaN             Degree  AADESH SHIVANAND GAONKAR
# 27815         10           NaN  College Demo Data                    VEERAJ
# 39653        379           NaN                 BE     Neha Gajanana Pandith
# 44286         16           NaN  College Demo Data               AMRUTHA K B
# 47483        735  College Demo                NaN            POOJA V SHETTY
# 47488        740  College Demo                NaN                CHAITHRA G
# 50537       5841           NaN                 ig             preethi patel
#
#       CONTACT NUMBER Unnamed: 5 Unnamed: 6               PLACE    Assigned To  \
# 26656     8861929019        NaN        NaN      UTTARA KANNADA            NaN
# 27815     7349162817        NaN        NaN                 NaN            NaN
# 39653     8453377709        NaN        NaN           Kundapura            NaN
# ...

# %%
print(df.loc[df['Willing to Attend Session? Y/N'] == 'mtech'])
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 NAME OF THE STUDENT CONTACT NUMBER  \
# 5453        206        NaN         BE     Gautham Halsnad     9449773180
# 5509        212        NaN         BE   Ashitha D Pattabi     9448260563
# 6695       1080      AMCAT        NaN      Ankita Singh S     9845130768
#
#      Unnamed: 5 Unnamed: 6       PLACE Assigned To      Unnamed: 9  \
# 5453        NaN        NaN   Kundapura         NaN  Not Interested
# 5509        NaN        NaN     Kotekar         NaN  Not Interested
# 6695        NaN        NaN  Whitefield         NaN  Not Interested
#
#      Call Back Date          Unnamed: 11 Remarks  \
# 5453            NaN  2020-09-21 00:00:00     NaN
# 5509            NaN  2020-09-21 00:00:00     NaN
# 6695            NaN  2020-10-16 00:00:00     NaN
#
#      Willing to Attend Session? Y/N Unnamed: 14
# 5453                          mtech         NaN
# 5509                          mtech         NaN
# 6695                          mtech         NaN

# %%
print(df.loc[df['Remarks'] == 'mtech'])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, Unnamed: 2, NAME OF THE STUDENT, CONTACT NUMBER, Unnamed: 5, Unnamed: 6, PLACE, Assigned To, Unnamed: 9, Call Back Date, Unnamed: 11, Remarks, Willing to Attend Session? Y/N, Unnamed: 14]
# Index: []

# %%
print(df.loc[df['Willing to Attend Session? Y/N'] == 'placed'])
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2    NAME OF THE STUDENT CONTACT NUMBER  \
# 5452         205        NaN         BE              Gautham G     9449823123
# 5455         209        NaN         BE             Goutham Ag     9632933032
# 5460         214        NaN         BE        H Adasrha Nayak     9449365376
# 5466         220        NaN         BE     H S Sunag Hemmanna     8762369567
# 5469         223        NaN         BE               Harshith     9945372539
# ...          ...        ...        ...                    ...            ...
# 15398       8507      AMCAT        NaN              Sridhar V     9342059789
# 15498       7908      AMCAT        NaN          Shiva Kumar G     9901875832
# 15563       7973      AMCAT        NaN  Shounak Hemant Dahale     9663117660
# 15598       7521      AMCAT        NaN         Sanjita Suresh     8095652987
# 15641       7564      AMCAT        NaN    Santosh Satvik Lade     9620422113
#
# ...

# %%
print(df.loc[df['Remarks'] == 'mba'])
# Out:
#       Unnamed: 0         Unnamed: 1    Unnamed: 2  NAME OF THE STUDENT  \
# 26173       3262                NaN        Degree      N G DEEPA ACHAR
# 26706       6647                NaN        Degree      SWATHI B SHETTY
# 27887         30                NaN  College Demo           AKSHATHA S
# 28021         72                NaN  College Demo             DIVYA BM
# 31607       1276                NaN        Degree             NAMRATHA
# ...          ...                ...           ...                  ...
# 56361       4064             Degree           NaN       PRAPTHI R AMIN
# 56366       4069             Degree           NaN  PRARTHANA UPADHYAYA
# 56414       4167             Degree           NaN     PRATHIKSHA NAYAK
# 56485       4632             Degree           NaN   RANJITHA R POOJARY
# 57954         39  College Demo Data           NaN             RAKSHITH
#
#       CONTACT NUMBER               Unnamed: 5        Unnamed: 6  PLACE  \
# ...

# %%
print(df.loc[df['Willing to Attend Session? Y/N'] == 'mcom'])
# Out:
#       Unnamed: 0 Unnamed: 1         Unnamed: 2 NAME OF THE STUDENT  \
# 301          106        NaN                NaN    GAYATHRI NAYAK M
# 384          448        NaN                NaN      MANISHA SHETTY
# 387          453        NaN                NaN          SOWJANYA G
# 428          445        NaN                NaN         RASHMITHA.R
# 429          361        NaN                NaN           Savitha a
# 430          362        NaN                NaN          Deepashree
# 457          197        NaN                NaN            VIGHNESH
# 490          306        NaN                NaN             KARTHIK
# 499          321        NaN                NaN        NAVEEN KULAL
# 1973        4826        NaN             Degree          RIYA LEWIS
# 4173          37        NaN  College Demo Data     SWHITHRA SHETTY
# 4188          56        NaN  College Demo Data             MANISHA
# 4262          44        NaN  College Demo Data      PREKSHITHA Y S
# ...

# %%
print(df.loc[df['Remarks'] == 'mcom'])
# Out:
#       Unnamed: 0         Unnamed: 1    Unnamed: 2  NAME OF THE STUDENT  \
# 26205       3294                NaN        Degree          NAGALAKSHMI
# 27905        NaN                NaN  College Demo                DEEPA
# 27937        NaN                NaN  College Demo         BHOOMIKA G S
# 28012         63                NaN  College Demo           ANISHA H A
# 29938       1244                NaN           NaN           PRATHIKSHA
# ...          ...                ...           ...                  ...
# 54993        327                NaN           NaN  FATHIMATH NISHANA S
# 54995        328                NaN           NaN             PAVITHRA
# 56313       4016             Degree           NaN      PRAKYATH N JAIN
# 56557       5460             Degree           NaN       SHAINY D SOUZA
# 58037         14  College Demo Data           NaN       MANISHAPOOJARY
#
#       CONTACT NUMBER Unnamed: 5 Unnamed: 6  PLACE   Assigned To  \
# ...

# %%
df.drop('Unnamed: 1', inplace=True, axis=1)

# %%
print(df)
# Out:
#       Unnamed: 0    Unnamed: 2      NAME OF THE STUDENT CONTACT NUMBER  \
# 0             51           PUC         SHIVANI R SHETTY     8453850949
# 1             52           PUC           MOHAMMED SINAN     8546876077
# 2             53           PUC  GOWRISH RAMESH SOMAYAJI     8548828521
# 3             54           PUC            AKSHAJ BAKHLE     8554821999
# 4             55           PUC              ANUSHA SHET     8618739902
# ...          ...           ...                      ...            ...
# 59421         46  College demo                DEEPTHI N     9741866821
# 59422         47  College demo             ANUKIRANA AV     7760502341
# 59423         48  College demo                NIHA BANU     9741721808
# 59424         49  College demo                  ROJA HG     7624826633
# 59425         50  College demo            PRINYANKA M,S     8861756646
#
#        Unnamed: 5 Unnamed: 6  PLACE   Assigned To                  Unnamed: 9  \
# ...

# %%
df.drop(['Unnamed: 0','Unnamed: 2'], inplace=True, axis=1)

# %%
print(df)
# Out:
#            NAME OF THE STUDENT CONTACT NUMBER  Unnamed: 5 Unnamed: 6  PLACE  \
# 0             SHIVANI R SHETTY     8453850949       SU021        NaN  UDUPI
# 1               MOHAMMED SINAN     8546876077       SU021        NaN  UDUPI
# 2      GOWRISH RAMESH SOMAYAJI     8548828521       SU021        NaN  UDUPI
# 3                AKSHAJ BAKHLE     8554821999       SU021        NaN  UDUPI
# 4                  ANUSHA SHET     8618739902       SU021        NaN  UDUPI
# ...                        ...            ...         ...        ...    ...
# 59421                DEEPTHI N     9741866821  Shivamogga        NaN    NaN
# 59422             ANUKIRANA AV     7760502341  Shivamogga        NaN    NaN
# 59423                NIHA BANU     9741721808  Shivamogga        NaN    NaN
# 59424                  ROJA HG     7624826633  Shivamogga        NaN    NaN
# 59425            PRINYANKA M,S     8861756646  Shivamogga        NaN    NaN
#
# ...

# %%
df.drop(['Unnamed: 5','Unnamed: 6'], inplace=True, axis=1)

# %%
print(df)
# Out:
#            NAME OF THE STUDENT CONTACT NUMBER  PLACE   Assigned To  \
# 0             SHIVANI R SHETTY     8453850949  UDUPI  Telecaller 5
# 1               MOHAMMED SINAN     8546876077  UDUPI  Telecaller 5
# 2      GOWRISH RAMESH SOMAYAJI     8548828521  UDUPI  Telecaller 5
# 3                AKSHAJ BAKHLE     8554821999  UDUPI  Telecaller 5
# 4                  ANUSHA SHET     8618739902  UDUPI  Telecaller 5
# ...                        ...            ...    ...           ...
# 59421                DEEPTHI N     9741866821    NaN           NaN
# 59422             ANUKIRANA AV     7760502341    NaN           NaN
# 59423                NIHA BANU     9741721808    NaN           NaN
# 59424                  ROJA HG     7624826633    NaN           NaN
# 59425            PRINYANKA M,S     8861756646    NaN           NaN
#
#                        Unnamed: 9       Call Back Date          Unnamed: 11  \
# 0                  Not Interested                  NaN  2020-06-10 00:00:00
# ...

# %%
df
# Out:
#            NAME OF THE STUDENT CONTACT NUMBER  PLACE   Assigned To  \
# 0             SHIVANI R SHETTY     8453850949  UDUPI  Telecaller 5
# 1               MOHAMMED SINAN     8546876077  UDUPI  Telecaller 5
# 2      GOWRISH RAMESH SOMAYAJI     8548828521  UDUPI  Telecaller 5
# 3                AKSHAJ BAKHLE     8554821999  UDUPI  Telecaller 5
# 4                  ANUSHA SHET     8618739902  UDUPI  Telecaller 5
# ...                        ...            ...    ...           ...
# 59421                DEEPTHI N     9741866821    NaN           NaN
# 59422             ANUKIRANA AV     7760502341    NaN           NaN
# 59423                NIHA BANU     9741721808    NaN           NaN
# 59424                  ROJA HG     7624826633    NaN           NaN
# 59425            PRINYANKA M,S     8861756646    NaN           NaN
#
#                        Unnamed: 9       Call Back Date          Unnamed: 11  \
# 0                  Not Interested                  NaN  2020-06-10 00:00:00
# ...

# %%
df.drop(['Unnamed: 9','Unnamed: 11','Unnamed: 14','Assigned To','Call Back Date'], inplace=True, axis=1)

# %%
df
# Out:
#            NAME OF THE STUDENT CONTACT NUMBER  PLACE         Remarks  \
# 0             SHIVANI R SHETTY     8453850949  UDUPI             NaN
# 1               MOHAMMED SINAN     8546876077  UDUPI             NaN
# 2      GOWRISH RAMESH SOMAYAJI     8548828521  UDUPI             NaN
# 3                AKSHAJ BAKHLE     8554821999  UDUPI             NaN
# 4                  ANUSHA SHET     8618739902  UDUPI             NaN
# ...                        ...            ...    ...             ...
# 59421                DEEPTHI N     9741866821    NaN             NaN
# 59422             ANUKIRANA AV     7760502341    NaN             NaN
# 59423                NIHA BANU     9741721808    NaN             NaN
# 59424                  ROJA HG     7624826633    NaN  higher studies
# 59425            PRINYANKA M,S     8861756646    NaN             NaN
#
#       Willing to Attend Session? Y/N
# 0                                  0
# 1                                  0
# ...

# %%
print(df)
# Out:
#            NAME OF THE STUDENT CONTACT NUMBER  PLACE         Remarks  \
# 0             SHIVANI R SHETTY     8453850949  UDUPI             NaN
# 1               MOHAMMED SINAN     8546876077  UDUPI             NaN
# 2      GOWRISH RAMESH SOMAYAJI     8548828521  UDUPI             NaN
# 3                AKSHAJ BAKHLE     8554821999  UDUPI             NaN
# 4                  ANUSHA SHET     8618739902  UDUPI             NaN
# ...                        ...            ...    ...             ...
# 59421                DEEPTHI N     9741866821    NaN             NaN
# 59422             ANUKIRANA AV     7760502341    NaN             NaN
# 59423                NIHA BANU     9741721808    NaN             NaN
# 59424                  ROJA HG     7624826633    NaN  higher studies
# 59425            PRINYANKA M,S     8861756646    NaN             NaN
#
#       Willing to Attend Session? Y/N
# 0                                  0
# 1                                  0
# ...

# %%
df.loc[df['Willing to Attend Session? Y/N'] == 'mba']
# Out:
#          NAME OF THE STUDENT CONTACT NUMBER                PLACE  \
# 385             PRIYANKA B S     8296574692                  NaN
# 448                SHRIRAKSH     9591394972                  NaN
# 1032           H S DEEKSHITH     9480491427                UDUPI
# 1235               M MAHESHA     9741133643                UDUPI
# 2026              SHASHANK Y     8762211994                UDUPI
# 2100        SUMANTH S SHETTY     9845634850                UDUPI
# 2191   WICKY STEPHEN D SOUZA     9164896478                UDUPI
# 4146                  FAUZIN     8722776562                  NaN
# 4159          NITHESH SHETTY     7483501562                  NaN
# 4168         AMRUTHA R ADIGA     8762383057                  NaN
# 4181            PRATHIKSHA K     8088664823                  NaN
# 4183       SUJITH S DEVADIGA     8496004407                  NaN
# 4187               VANISHREE     7019872480                  NaN
# ...
